# %%
from IPython.display import clear_output

# %%
import sys
sys.path.append('/Users/belle/Library/Python/3.7/lib/python/site-packages')

from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
import pandas as pd
import numpy as np

# %%
API_KEY = open('google-api-key.txt', 'r').read()
youtube_service = build('youtube', 'v3', developerKey=API_KEY)

# %%
channels = pd.DataFrame.from_records([
    {'title': 'Fox News', 'slug': 'fox-news', 'youtube_id': 'UCXIJgqnII2ZOINSWNOGFThA', 'playlist_id': 'UUXIJgqnII2ZOINSWNOGFThA', 'url': 'https://www.youtube.com/user/FoxNewsChannel', 'color': '#5975a4'},
    {'title': 'CNN', 'slug': 'cnn', 'youtube_id': 'UCupvZG-5ko_eiXAupbDfxWw', 'playlist_id': 'UUupvZG-5ko_eiXAupbDfxWw', 'url': 'https://www.youtube.com/user/CNN', 'color': '#b55d60'},
    {'title': 'MSNBC', 'slug': 'msnbc', 'youtube_id': 'UCaXkIU1QidjPwiAYu6GcHjg', 'playlist_id': 'UUaXkIU1QidjPwiAYu6GcHjg', 'url': 'https://www.youtube.com/user/msnbcleanforward', 'color': '#5f9e6e'},
    {'title': 'CBS News', 'slug': 'cbs-news', 'youtube_id': 'UC8p1vwvWtl6T73JiExfWs1g', 'playlist_id': 'UU8p1vwvWtl6T73JiExfWs1g', 'url': 'https://www.youtube.com/user/CBSNewsOnline', 'color': '#666666'},
])

channels.to_csv('channels.csv', index=False, encoding='utf-8')

# %%
channel_df = pd.read_csv('channels.csv')

# %%
channel_df.head(5)
# Out:
#       title      slug                youtube_id               playlist_id  \
# 0  Fox News  fox-news  UCXIJgqnII2ZOINSWNOGFThA  UUXIJgqnII2ZOINSWNOGFThA
# 1       CNN       cnn  UCupvZG-5ko_eiXAupbDfxWw  UUupvZG-5ko_eiXAupbDfxWw
# 2     MSNBC     msnbc  UCaXkIU1QidjPwiAYu6GcHjg  UUaXkIU1QidjPwiAYu6GcHjg
# 3  CBS News  cbs-news  UC8p1vwvWtl6T73JiExfWs1g  UU8p1vwvWtl6T73JiExfWs1g
#
#                                              url    color
# 0    https://www.youtube.com/user/FoxNewsChannel  #5975a4
# 1               https://www.youtube.com/user/CNN  #b55d60
# 2  https://www.youtube.com/user/msnbcleanforward  #5f9e6e
# 3     https://www.youtube.com/user/CBSNewsOnline  #666666

# %%
topics = pd.DataFrame.from_records([
    {'title': 'Biden', 'slug': 'biden', 'variant1': 'Biden', 'variant2': 'Bidens'},
    {'title': 'Trump', 'slug': 'trump','variant1': 'Trump', 'variant2': 'Trumps'},
    {'title': 'Democrats', 'slug': 'democrats', 'variant1': 'Democrat', 'variant2': 'Democrats'},
    {'title': 'Republicans', 'slug': 'republicans', 'variant1': 'Republican', 'variant2': 'Republicans'},
    {'title': 'Liberals', 'slug': 'liberals', 'variant1': 'Liberal', 'variant2': 'Liberals'},
    {'title': 'Conservatives', 'slug': 'conservatives', 'variant1': 'Conservative', 'variant2': 'Conservatives'},
])

topics.to_csv('topics.csv', index=False, encoding='utf-8')

# %%
from youtube_api import download_channels_videos

download_channels_videos(channels)
# Out:
# Downloading videos from "Fox News": 15...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-28-93273e75e4b4> in <module>
#       1 from youtube_api import download_channels_videos
#       2
# ----> 3 download_channels_videos(channels)
#
# ~/Documents/GitHub/senior-thesis/youtube_api.py in download_channels_videos(channels)
#      48     """
#      49     for _, channel in channels.iterrows():
# ---> 50         videos = download_channel_videos(channel) # modified line
#      51         df = pd.DataFrame.from_records(videos)
#      52         output_file = 'videos-{}.csv'.format(channel['slug'])
#
# ~/Documents/GitHub/senior-thesis/youtube_api.py in download_channel_videos(channel)
#      22     pageToken = None
#      23     while True:
# ---> 24         response = youtube_service.playlistItems().list(playlistId=channel['playlist_id'], part="snippet", pageToken=pageToken).execute()
#      25         for video in response['items']:
#      26             videos.append({
#
# ~/Library/Python/3.7/lib/python/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# ~/Library/Python/3.7/lib/python/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/playlistItems?playlistId=UUXIJgqnII2ZOINSWNOGFThA&part=snippet&pageToken=EAAaBlBUOkNBOA&key=AIzaSyDBCYBqXkjfTSeSrmPvZZP5ONAQgOCDBfA&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
fox = pd.read_csv('videos-fox-news.csv')
cnn = pd.read_csv('videos-cnn.csv')

# %%
fox.head(5)
# Out:
#     youtube_id                                              title  \
# 0  VXWGqpkAqm8      This has created a culture of fear: Ramaswamy
# 1  TNdfTRTeT-Q  Biden hosts a joint press conference with Pres...
# 2  oQZaJ-_EOsU      White House slammed for lavish lobster dinner
# 3  xglf1OtGcVo  Celebs torched for silence on Balenciaga: 'The...
# 4  erQjPWBCRmA  'Yuck!': NY Times slammed for 'cozy' interview...
#
#                                          description          published_at  \
# 0  Strive Asset Management founder Vivek Ramaswam...  2022-12-01T21:45:15Z
# 1  President Biden hosts a joint press conference...  2022-12-01T21:44:24Z
# 2  ‘Outnumbered’ on President Biden’s ‘ridiculous...  2022-12-01T21:15:00Z
# 3  'Outnumbered' panel discuss the silence from c...  2022-12-01T20:30:04Z
# 4  The panel discussed SBF's interview with the N...  2022-12-01T19:45:01Z
#
#          channel_youtube_id
# 0  UCXIJgqnII2ZOINSWNOGFThA
# 1  UCXIJgqnII2ZOINSWNOGFThA
# 2  UCXIJgqnII2ZOINSWNOGFThA
# 3  UCXIJgqnII2ZOINSWNOGFThA
# 4  UCXIJgqnII2ZOINSWNOGFThA

# %%
scraped_channels = pd.DataFrame.from_records([
    {'title': 'Fox News', 'slug': 'fox-news', 'youtube_id': 'UCXIJgqnII2ZOINSWNOGFThA', 'playlist_id': 'UUXIJgqnII2ZOINSWNOGFThA', 'url': 'https://www.youtube.com/user/FoxNewsChannel', 'color': '#5975a4'},
    {'title': 'CNN', 'slug': 'cnn', 'youtube_id': 'UCupvZG-5ko_eiXAupbDfxWw', 'playlist_id': 'UUupvZG-5ko_eiXAupbDfxWw', 'url': 'https://www.youtube.com/user/CNN', 'color': '#b55d60'}
])

scraped_channels.to_csv('scraped_channels.csv', index=False, encoding='utf-8')

# %%
from youtube_api import merge_channel_videos
merge_channel_videos(scraped_channels)
# Out:
# Channel videos merged into videos-MERGED.csv

# %%
from utils import create_topic_columns

videos = pd.read_csv('videos-MERGED.csv')
create_topic_columns(videos, topics)
videos.to_csv('videos.csv', index=False, encoding='utf-8')

# %%
videos.head(10)
# Out:
#     youtube_id                                              title  \
# 0  VXWGqpkAqm8      This has created a culture of fear: Ramaswamy
# 1  TNdfTRTeT-Q  Biden hosts a joint press conference with Pres...
# 2  oQZaJ-_EOsU      White House slammed for lavish lobster dinner
# 3  xglf1OtGcVo  Celebs torched for silence on Balenciaga: 'The...
# 4  erQjPWBCRmA  'Yuck!': NY Times slammed for 'cozy' interview...
# 5  plr0xCPtePo  'Embarrassing': Will Cain blasts Elizabeth War...
# 6  XL7O0FmOxfw  Ceasefire! School board members call truce aft...
# 7  C-cEl0lmBKE    Charlie Gasparino: ‘This dude is going to jail’
# 8  SbzbxgyJNbE  Jon Levine: What Twitter did in 2020 was a 'te...
# 9  AxXQN11I4cw  Idaho police backtrack on key detail in colleg...
#
#                                          description          published_at  \
# 0  Strive Asset Management founder Vivek Ramaswam...  2022-12-01T21:45:15Z
# 1  President Biden hosts a joint press conference...  2022-12-01T21:44:24Z
# 2  ‘Outnumbered’ on President Biden’s ‘ridiculous...  2022-12-01T21:15:00Z
# 3  'Outnumbered' panel discuss the silence from c...  2022-12-01T20:30:04Z
# 4  The panel discussed SBF's interview with the N...  2022-12-01T19:45:01Z
# 5  'Fox & Friends Weekend' co-host Will Cain weig...  2022-12-01T19:00:13Z
# 6  After a year of fighting over equity policies ...  2022-12-01T18:15:01Z
# 7  FOX Business senior correspondent Charlie Gasp...  2022-12-01T17:15:00Z
# 8  New York Post reporter Jon Levine unpacks deve...  2022-12-01T16:15:01Z
# 9  Correspondent Anita Vogel reports the latest o...  2022-12-01T15:30:02Z
#
#          channel_youtube_id   channel  relevant  obama  trump  democrats  \
# 0  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 1  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 2  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 3  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 4  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 5  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 6  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 7  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 8  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
# 9  UCXIJgqnII2ZOINSWNOGFThA  Fox News     False  False  False      False
#
#    republicans  liberals  conservatives
# 0        False     False          False
# 1        False     False          False
# 2        False     False          False
# 3        False     False          False
# 4        False     False          False
# 5        False     False          False
# 6        False     False          False
# 7        False     False          False
# 8        False     False          False
# 9        False     False          False

# %%
videos.shape
# Out:
# (39013, 13)

# %%
videos[videos['relevant'] == True]
# Out:
#         youtube_id                                              title  \
# 10     eLTXIJUBYUI  Tucker exposes how liberals are exempt from ca...
# 17     PmbKFeDZPVo  Ingraham: Republicans are going to cave on ano...
# 26     N4GdcUOIVkw  Gutfeld: This is why Democrats can't agree wit...
# 51     4eDgh52shLY  Sean Hannity mocks Don Lemon for claiming CNN ...
# 56     BNadO1fRY28  Liberal actress claims Elon Musk's Twitter is ...
# ...            ...                                                ...
# 38998  cxcboiRBIUI   Trump: North Korea statement wasn't tough enough
# 39004  Guk68xKTMhE  Commentator calls Trump's North Korea comments...
# 39006  3Ej2xz7-SuQ  President Trump slams Sen. Mitch McConnell in ...
# 39009  EuiBh4M50nA  Sparks fly over Trump's "fire and fury" North ...
# 39010  1-1WE-ivtO4   What Trump said about North Korean nukes in 1999
#
#                                              description  \
# 10     Fox News host Tucker Carlson calls out hypocri...
# 17     Holding the Republican establishment accountab...
# 26     'Gutfeld!' panelists weigh in on the Democrats...
# 51     Fox News host Sean Hannity highlights Don Lemo...
# 56     Fox News contributor Joe Concha discusses actr...
# ...                                                  ...
# 38998  President Trump says that perhaps his "fire an...
# 39004  CNN political commentator Ana Navarro says Pre...
# 39006  President Donald Trump resumed his public feud...
# 39009  CNN political commentator Ben Ferguson and Rep...
# 39010  In a 1999 interview with CNN's Wolf Blitzer, D...
#
#                published_at        channel_youtube_id   channel  relevant  \
# 10     2022-12-01T15:00:32Z  UCXIJgqnII2ZOINSWNOGFThA  Fox News      True
# 17     2022-12-01T11:30:06Z  UCXIJgqnII2ZOINSWNOGFThA  Fox News      True
# 26     2022-12-01T05:00:15Z  UCXIJgqnII2ZOINSWNOGFThA  Fox News      True
# 51     2022-11-30T16:00:04Z  UCXIJgqnII2ZOINSWNOGFThA  Fox News      True
# 56     2022-11-30T14:30:01Z  UCXIJgqnII2ZOINSWNOGFThA  Fox News      True
# ...                     ...                       ...       ...       ...
# 38998  2017-08-10T19:08:35Z  UCupvZG-5ko_eiXAupbDfxWw       CNN      True
# 39004  2017-08-10T14:46:32Z  UCupvZG-5ko_eiXAupbDfxWw       CNN      True
# 39006  2017-08-10T14:42:04Z  UCupvZG-5ko_eiXAupbDfxWw       CNN      True
# 39009  2017-08-09T22:31:53Z  UCupvZG-5ko_eiXAupbDfxWw       CNN      True
# 39010  2017-08-09T22:11:09Z  UCupvZG-5ko_eiXAupbDfxWw       CNN      True
#
#        obama  trump  democrats  republicans  liberals  conservatives
# 10     False  False      False        False      True          False
# 17     False  False      False         True     False          False
# 26     False  False       True         True     False          False
# 51     False  False      False        False      True          False
# 56     False  False      False        False      True          False
# ...      ...    ...        ...          ...       ...            ...
# 38998  False   True      False        False     False          False
# 39004  False   True      False        False     False          False
# 39006  False   True      False        False     False          False
# 39009  False   True      False        False     False          False
# 39010  False   True      False        False     False          False
#
# [8789 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-e8eb59de0ca9> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from wordcloud import WordCloud
#
# ~/Library/Python/3.7/lib/python/site-packages/wordcloud/__init__.py in <module>
# ----> 1 from .wordcloud import (WordCloud, STOPWORDS, random_color_func,
#       2                         get_single_color_func)
#       3 from .color_from_image import ImageColorGenerator
#       4
#       5 __all__ = ['WordCloud', 'STOPWORDS', 'random_color_func',
#
# ~/Library/Python/3.7/lib/python/site-packages/wordcloud/wordcloud.py in <module>
#      28 from PIL import ImageFont
#      29
# ---> 30 from .query_integral_image import query_integral_image
#      31 from .tokenization import unigrams_and_bigrams, process_tokens
#      32
#
# ModuleNotFoundError: No module named 'wordcloud.query_integral_image'

# %%
import string

# %%
relevant_fox = videos[(videos['relevant'] == True) & (videos['channel'] == 'Fox News')]

# %%
title_split_fox = relevant_fox['title'].str.translate(str.maketrans('', '', string.punctuation))

# %%
title_split_fox = title_split_fox.str.cat(sep=' ')

# %%
title_split_fox
# Out:
# 'Tucker exposes how liberals are exempt from cancel culture shorts Ingraham Republicans are going to cave on another huge issue Gutfeld This is why Democrats cant agree with Republicans Sean Hannity mocks Don Lemon for claiming CNN never had a liberal bias shorts Liberal actress claims Elon Musks Twitter is now a turf war Don Lemon downplays CNN’s liberal leanings shorts Liberal journalists contradict each other over the border shorts Outnumbered roasts Don Lemon for claiming CNN was never liberal Democrats keeping Biden out of Georgia before runoff Fauci blasts Republicans for pushing antiFauci messaging Jackie DeAngelis Republican Party is fragmented and fractured The Five Bill Maher rips Democrats over woke education Biden picked up the mantra from Barack Obama Victor Davis Hanson Gutfeld Who is likely to challenge Trump in 2024 McCarthy is making Democrats confront the problem they created Duffy Rep Carter People of Georgia know we need a conservative voice Watch Obama Schumer’s drastic flipflop on immigration shorts Tulsi Gabbard The liberal media is on full damage control The Five Liberals wage war on Thanksgiving Former Trump adviser There is a humanitarian crisis at the border Liberal mayor taken to court over First Amendment attack Top Republican ridicules CBS News finally verifying Hunter Biden laptop story Arizona Democrat calls out his party Not even close Joe Concha The media certainly wont help House Republicans Gutfeld on Donald Trumps Twitter account being reinstated Kayleigh McEnany Liberals call to cancel Thanksgiving shorts Andy McCarthy on Trump investigation This is a lot of theater Top Democrat admits Trump was right Gowdy Republicans save their sharpest knives for each other Jimmy Failla Here’s why Trump leaving Twitter was the worst thing for Dems Liberal media has complete meltdown over Trump’s Twitter reinstatement Jimmy Failla shorts Tucker Carlson This is the only thing Obama has said that I agree with  The Janice Dean Podcast Elon Musk confirms Trump will be reinstated on Twitter Tucker torpedoes liberals for attacking free speech shorts AG Garland announces multiple Trump investigations Former Trump acting AG responds to DOJs latest stunt The Five Liberal cities go soft on crime Jesse Watters Democrats are allergic to the truth Judge Jeanine Liberal journalists melt down over Elon Musk’s Twitter shorts Jonathan Turley This is a serious concern for Trump AG Garland announces special counsel to investigate Trump AG Garland to appoint special counsel in Trump MaraLago Jan 6 probes Liberal media gives NBC a pass after retracting Paul Pelosi attack story Jesse Watters roasts Michelle Obamas take on dealing with the press shorts Watters Whats next for Democrats Undermining US democracy lets China exploit our weakness liberal author Pelosi subtly digs at Trump in monumental House speech Pence responds to Trump saying he would be disloyal if he runs in 2024 Brian Kilmeade Show Trump Now we have a president who falls asleep at global conferences shorts Liberal citys DA facing impeachment vote as crime soars This is the biggest question about Trump and DeSantis McGurn Republicans are one seat away from House majority Ivanka Trump makes surprise announcement about 2024 campaign Mike Pence America will have ‘better choices’ than Trump Trump announces 2024 presidential run shorts Hannity has breaking analysis of Trump announcing third presidential bid Former President Donald Trump makes a special announcement Donald Trump announces 2024 reelection run for president Michelle Obama stumbles on endorsing Biden in 2024 shorts DeSantis responds to Trump criticism Check the scoreboard House Republicans one seat away from claiming majority Republicans only one seat away from securing House majority Kellyanne Conway This is how Trump could defy naysayers in 2024 Democrat Katie Hobbs projected to defeat Kari Lake Sen Josh Hawley Republicans werent offering what independents wanted The 2022 House Republican Party will b ...

# %%
fox_title_text = open("fox_title_text.txt", "w")
n = fox_title_text.write(title_split_fox)
fox_title_text.close()

# %%
videos.loc[10,:]['title']
# Out:
# youtube_id                                                  eLTXIJUBYUI
# title                 Tucker exposes how liberals are exempt from ca...
# description           Fox News host Tucker Carlson calls out hypocri...
# published_at                                       2022-12-01T15:00:32Z
# channel_youtube_id                             UCXIJgqnII2ZOINSWNOGFThA
# channel                                                        Fox News
# relevant                                                           True
# obama                                                             False
# trump                                                             False
# democrats                                                         False
# republicans                                                       False
# liberals                                                           True
# conservatives                                                     False
# Name: 10, dtype: object

# %%
relevant_cnn = videos[(videos['relevant'] == True) & (videos['channel'] == 'CNN')]
title_split_cnn = relevant_cnn['title'].str.translate(str.maketrans('', '', string.punctuation))
title_split_cnn = title_split_cnn.str.cat(sep=' ')

# %%
cnn_title_text = open("cnn_title_text.txt", "w")
n = cnn_title_text.write(title_split_cnn)
cnn_title_text.close()

# %%
relevant_cnn.head(5)
# Out:
#         youtube_id                                              title  \
# 19738  Ob8n_nkjh0E  Obama campaigns in Georgia as early voting sur...
# 19745  uX4aMPsD_mM  House committee receives Trump’s federal tax r...
# 19751  e_NvSkrRsJY  Democrats pick Jeffries for House leadership r...
# 19756  ebHO9Niwiss  Analysis: One of Trump's biggest defenders thi...
# 19760  yUExQwX-QaY  Berman calls out Kevin McCarthy’s response to ...
#
#                                              description  \
# 19738  Former President Barack Obama returned to Geor...
# 19745  The House Ways and Means Committee now has six...
# 19751  House Democrats chose Rep. Hakeem Jeffries of ...
# 19756  The GOP is in the middle on an internal disput...
# 19760  CNN’s John Berman breaks down the response fro...
#
#                published_at        channel_youtube_id channel  relevant  \
# 19738  2022-12-01T15:49:42Z  UCupvZG-5ko_eiXAupbDfxWw     CNN      True
# 19745  2022-12-01T02:56:57Z  UCupvZG-5ko_eiXAupbDfxWw     CNN      True
# 19751  2022-11-30T18:57:56Z  UCupvZG-5ko_eiXAupbDfxWw     CNN      True
# 19756  2022-11-30T13:32:13Z  UCupvZG-5ko_eiXAupbDfxWw     CNN      True
# 19760  2022-11-30T02:16:01Z  UCupvZG-5ko_eiXAupbDfxWw     CNN      True
#
#        obama  trump  democrats  republicans  liberals  conservatives
# 19738   True  False      False        False     False          False
# 19745  False   True      False        False     False          False
# 19751  False  False       True        False     False          False
# 19756  False   True      False        False     False          False
# 19760  False   True      False        False     False          False
